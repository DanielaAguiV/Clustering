# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from utils.silhoutte_analysis import silhoutte_plot
from utils.distances import calculate_distances

# %%
X, y = make_blobs(n_samples=500,n_features=2,centers=4,cluster_std=1,center_box=(-10.0, 10.0),shuffle=True,random_state=1,)
plt.title("Unclustered Data")
plt.scatter(X[:, 0], X[:, 1], s=15)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
silhoutte_plot('Kmeans',X,5)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.4706753453390015
# For n_clusters = 3 The average silhouette_score is : 0.4369251936015581
# For n_clusters = 4 The average silhouette_score is : 0.5581994918185206
# For n_clusters = 5 The average silhouette_score is : 0.34087997425882816

# %%
silhoutte_plot('Kmedoids',X,5)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.7049787496083262
# For n_clusters = 3 The average silhouette_score is : 0.5673099267394572
# For n_clusters = 4 The average silhouette_score is : 0.6505186632729437
# For n_clusters = 5 The average silhouette_score is : 0.45738115078830427

# %% [markdown]
# Para ambos métodos se evidencia que el numero optimo de cluster es el 4 , ya que en ambos casos con K = 4, se ve que las figuras de silhouette pasan el punto de silhouette score y esto nos permite determinar que tan bien hace la separabilidad, además se puede ver en ambos casos que funciona mucho mejor tener dos cluster que 3, y dada la forma de lo clusters estos resultados son los esperados.
